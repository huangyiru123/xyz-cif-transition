# %%
import os
import re
import numpy as np
from ase.io import read

def parse_lattice(line: str):
    """从字符串 'Lattice="a1 a2 a3 b1 b2 b3 c1 c2 c3"' 解析晶格矩阵"""
    match = re.search(r'Lattice="([^"]+)"', line)
    if not match:
        raise ValueError("No lattice found in XYZ comment line.")
    values = list(map(float, match.group(1).split()))
    return np.array(values).reshape(3, 3)

def xyz_to_cif(xyz_path, cif_path):
    """转换单个 XYZ 文件到 CIF，保留晶格信息"""
    with open(xyz_path, 'r') as f:
        lines = f.readlines()
    
    # 提取晶格（假设第二行是注释行，如 'Lattice="..." Properties=...'）
    lattice = parse_lattice(lines[1]) if len(lines) > 1 else None
    
    # 读取原子数据（跳过前两行）
    atoms = read(xyz_path, format='xyz')
    if lattice is not None:
        atoms.set_cell(lattice)
        atoms.set_pbc([True, True, True])
    
    # 写入 CIF 文件
    with open(cif_path, 'w') as f:
        f.write(f"data_{os.path.splitext(os.path.basename(xyz_path))[0]}\n")
        if lattice is not None:
            a, b, c = np.linalg.norm(lattice, axis=1)
            alpha = np.degrees(np.arccos(np.dot(lattice[1], lattice[2]) / (b * c)))
            beta  = np.degrees(np.arccos(np.dot(lattice[0], lattice[2]) / (a * c)))
            gamma = np.degrees(np.arccos(np.dot(lattice[0], lattice[1]) / (a * b)))
            f.write(f"_cell_length_a      {a:.6f}\n")
            f.write(f"_cell_length_b      {b:.6f}\n")
            f.write(f"_cell_length_c      {c:.6f}\n")
            f.write(f"_cell_angle_alpha   {alpha:.6f}\n")
            f.write(f"_cell_angle_beta    {beta:.6f}\n")
            f.write(f"_cell_angle_gamma   {gamma:.6f}\n")
        f.write("_space_group_name_H-M_alt 'P 1'\n")
        f.write("loop_\n  _atom_site_type_symbol\n  _atom_site_label\n  _atom_site_fract_x\n  _atom_site_fract_y\n  _atom_site_fract_z\n")
        
        # 写入原子（分数坐标）
        for i, atom in enumerate(atoms):
            symbol = atom.symbol
            pos = atom.position
            if lattice is not None:
                frac_pos = np.linalg.solve(lattice.T, pos).flatten()  # 直角坐标 → 分数坐标
            else:
                frac_pos = pos  # 无晶格时直接使用直角坐标
            f.write(f"{symbol}  {symbol}{i+1}  {frac_pos[0]:.6f}  {frac_pos[1]:.6f}  {frac_pos[2]:.6f}\n")

# 批量处理所有 structure_* 文件夹
root_dir = "visualization"
for folder in os.listdir(root_dir):
    if folder.startswith("structure_"):
        folder_path = os.path.join(root_dir, folder)
        for file in os.listdir(folder_path):
            if file.endswith(".xyz"):
                xyz_path = os.path.join(folder_path, file)
                cif_path = os.path.join(folder_path, file.replace(".xyz", ".cif"))
                try:
                    xyz_to_cif(xyz_path, cif_path)
                    print(f"Converted: {xyz_path} → {cif_path}")
                except Exception as e:
                    print(f"Failed to convert {xyz_path}: {str(e)}")
# Out:
# Converted: visualization/structure_0/train.xyz → visualization/structure_0/train.cif
# Converted: visualization/structure_0/cluster_0.xyz → visualization/structure_0/cluster_0.cif
# Converted: visualization/structure_0/cluster_1.xyz → visualization/structure_0/cluster_1.cif
# Converted: visualization/structure_0/cluster_2.xyz → visualization/structure_0/cluster_2.cif
# Converted: visualization/structure_0/cluster_3.xyz → visualization/structure_0/cluster_3.cif
# Converted: visualization/structure_1/train.xyz → visualization/structure_1/train.cif
# Converted: visualization/structure_1/cluster_0.xyz → visualization/structure_1/cluster_0.cif
# Converted: visualization/structure_1/cluster_1.xyz → visualization/structure_1/cluster_1.cif
# Converted: visualization/structure_1/cluster_2.xyz → visualization/structure_1/cluster_2.cif
# Converted: visualization/structure_2/train.xyz → visualization/structure_2/train.cif
# Converted: visualization/structure_2/cluster_0.xyz → visualization/structure_2/cluster_0.cif
# Converted: visualization/structure_2/cluster_1.xyz → visualization/structure_2/cluster_1.cif
# Converted: visualization/structure_3/train.xyz → visualization/structure_3/train.cif
# Converted: visualization/structure_3/cluster_0.xyz → visualization/structure_3/cluster_0.cif
# Converted: visualization/structure_3/cluster_1.xyz → visualization/structure_3/cluster_1.cif
# Converted: visualization/structure_3/cluster_2.xyz → visualization/structure_3/cluster_2.cif
# Converted: visualization/structure_3/cluster_3.xyz → visualization/structure_3/cluster_3.cif
# Converted: visualization/structure_3/cluster_4.xyz → visualization/structure_3/cluster_4.cif
# Converted: visualization/structure_3/cluster_5.xyz → visualization/structure_3/cluster_5.cif
# Converted: visualization/structure_4/train.xyz → visualization/structure_4/train.cif
# Converted: visualization/structure_4/cluster_0.xyz → visualization/structure_4/cluster_0.cif
# Converted: visualization/structure_4/cluster_1.xyz → visualization/structure_4/cluster_1.cif
# Converted: visualization/structure_4/cluster_2.xyz → visualization/structure_4/cluster_2.cif
# Converted: visualization/structure_5/train.xyz → visualization/structure_5/train.cif
# Converted: visualization/structure_5/cluster_0.xyz → visualization/structure_5/cluster_0.cif
# Converted: visualization/structure_5/cluster_1.xyz → visualization/structure_5/cluster_1.cif
# Converted: visualization/structure_5/cluster_2.xyz → visualization/structure_5/cluster_2.cif
# Converted: visualization/structure_6/train.xyz → visualization/structure_6/train.cif
# Converted: visualization/structure_6/cluster_0.xyz → visualization/structure_6/cluster_0.cif
# Converted: visualization/structure_6/cluster_1.xyz → visualization/structure_6/cluster_1.cif
# Converted: visualization/structure_6/cluster_2.xyz → visualization/structure_6/cluster_2.cif
# Converted: visualization/structure_6/cluster_3.xyz → visualization/structure_6/cluster_3.cif
# Converted: visualization/structure_6/cluster_4.xyz → visualization/structure_6/cluster_4.cif
# Converted: visualization/structure_6/cluster_5.xyz → visualization/structure_6/cluster_5.cif
# Converted: visualization/structure_6/cluster_6.xyz → visualization/structure_6/cluster_6.cif
# Converted: visualization/structure_6/cluster_7.xyz → visualization/structure_6/cluster_7.cif
# Converted: visualization/structure_6/cluster_8.xyz → visualization/structure_6/cluster_8.cif
# Converted: visualization/structure_6/cluster_9.xyz → visualization/structure_6/cluster_9.cif
# Converted: visualization/structure_6/cluster_10.xyz → visualization/structure_6/cluster_10.cif
# Converted: visualization/structure_6/cluster_11.xyz → visualization/structure_6/cluster_11.cif
# Converted: visualization/structure_6/cluster_12.xyz → visualization/structure_6/cluster_12.cif
# Converted: visualization/structure_7/train.xyz → visualization/structure_7/train.cif
# Converted: visualization/structure_7/cluster_0.xyz → visualization/structure_7/cluster_0.cif
# Converted: visualization/structure_8/train.xyz → visualization/structure_8/train.cif
# Converted: visualization/structure_8/cluster_0.xyz → visualization/structure_8/cluster_0.cif
# Converted: visualization/structure_9/train.xyz → visualization/structure_9/train.cif
# Converted: visualization/structure_9/cluster_0.xyz → visualization/structure_9/cluster_0.cif
# Converted: visualization/structure_9/cluster_1.xyz → visualization/structure_9/cluster_1.cif
# Converted: visualization/structure_10/train.xyz → visualization/structure_10/train.cif
# Converted: visualization/structure_10/cluster_0.xyz → visualization/structure_10/cluster_0.cif
# Converted: visualization/structure_10/cluster_1.xyz → visualization/structure_10/cluster_1.cif
# Converted: visualization/structure_10/cluster_2.xyz → visualization/structure_10/cluster_2.cif
# Converted: visualization/structure_10/cluster_3.xyz → visualization/structure_10/cluster_3.cif
# Converted: visualization/structure_10/cluster_4.xyz → visualization/structure_10/cluster_4.cif
# Converted: visualization/structure_10/cluster_5.xyz → visualization/structure_10/cluster_5.cif
# Converted: visualization/structure_10/cluster_6.xyz → visualization/structure_10/cluster_6.cif
# Converted: visualization/structure_11/train.xyz → visualization/structure_11/train.cif
# Converted: visualization/structure_11/cluster_0.xyz → visualization/structure_11/cluster_0.cif
# Converted: visualization/structure_11/cluster_1.xyz → visualization/structure_11/cluster_1.cif
# Converted: visualization/structure_11/cluster_2.xyz → visualization/structure_11/cluster_2.cif
# Converted: visualization/structure_12/train.xyz → visualization/structure_12/train.cif
# Converted: visualization/structure_12/cluster_0.xyz → visualization/structure_12/cluster_0.cif
# Converted: visualization/structure_12/cluster_1.xyz → visualization/structure_12/cluster_1.cif
# Converted: visualization/structure_12/cluster_2.xyz → visualization/structure_12/cluster_2.cif
# Converted: visualization/structure_13/train.xyz → visualization/structure_13/train.cif
# Converted: visualization/structure_13/cluster_0.xyz → visualization/structure_13/cluster_0.cif
# Converted: visualization/structure_13/cluster_1.xyz → visualization/structure_13/cluster_1.cif
# Converted: visualization/structure_13/cluster_2.xyz → visualization/structure_13/cluster_2.cif
# Converted: visualization/structure_13/cluster_3.xyz → visualization/structure_13/cluster_3.cif
# Converted: visualization/structure_14/train.xyz → visualization/structure_14/train.cif
# Converted: visualization/structure_14/cluster_0.xyz → visualization/structure_14/cluster_0.cif
# Converted: visualization/structure_14/cluster_1.xyz → visualization/structure_14/cluster_1.cif
# Converted: visualization/structure_14/cluster_2.xyz → visualization/structure_14/cluster_2.cif
# Converted: visualization/structure_14/cluster_3.xyz → visualization/structure_14/cluster_3.cif
# Converted: visualization/structure_14/cluster_4.xyz → visualization/structure_14/cluster_4.cif
# Converted: visualization/structure_15/train.xyz → visualization/structure_15/train.cif
# Converted: visualization/structure_15/cluster_0.xyz → visualization/structure_15/cluster_0.cif
# Converted: visualization/structure_16/train.xyz → visualization/structure_16/train.cif
# Converted: visualization/structure_16/cluster_0.xyz → visualization/structure_16/cluster_0.cif
# Converted: visualization/structure_16/cluster_1.xyz → visualization/structure_16/cluster_1.cif
# Converted: visualization/structure_16/cluster_2.xyz → visualization/structure_16/cluster_2.cif
# Converted: visualization/structure_17/train.xyz → visualization/structure_17/train.cif
# Converted: visualization/structure_17/cluster_0.xyz → visualization/structure_17/cluster_0.cif
# Converted: visualization/structure_17/cluster_1.xyz → visualization/structure_17/cluster_1.cif
# Converted: visualization/structure_18/train.xyz → visualization/structure_18/train.cif
# Converted: visualization/structure_18/cluster_0.xyz → visualization/structure_18/cluster_0.cif
# Converted: visualization/structure_19/train.xyz → visualization/structure_19/train.cif
# Converted: visualization/structure_19/cluster_0.xyz → visualization/structure_19/cluster_0.cif
# Converted: visualization/structure_19/cluster_1.xyz → visualization/structure_19/cluster_1.cif
# Converted: visualization/structure_19/cluster_2.xyz → visualization/structure_19/cluster_2.cif
# Converted: visualization/structure_19/cluster_3.xyz → visualization/structure_19/cluster_3.cif
# Converted: visualization/structure_19/cluster_4.xyz → visualization/structure_19/cluster_4.cif
# Converted: visualization/structure_19/cluster_5.xyz → visualization/structure_19/cluster_5.cif
# Converted: visualization/structure_20/train.xyz → visualization/structure_20/train.cif
# Converted: visualization/structure_20/cluster_0.xyz → visualization/structure_20/cluster_0.cif
# Converted: visualization/structure_20/cluster_1.xyz → visualization/structure_20/cluster_1.cif
# Converted: visualization/structure_20/cluster_2.xyz → visualization/structure_20/cluster_2.cif
# Converted: visualization/structure_20/cluster_3.xyz → visualization/structure_20/cluster_3.cif
# Converted: visualization/structure_21/train.xyz → visualization/structure_21/train.cif
# Converted: visualization/structure_21/cluster_0.xyz → visualization/structure_21/cluster_0.cif
# Converted: visualization/structure_21/cluster_1.xyz → visualization/structure_21/cluster_1.cif
# Converted: visualization/structure_21/cluster_2.xyz → visualization/structure_21/cluster_2.cif
# Converted: visualization/structure_21/cluster_3.xyz → visualization/structure_21/cluster_3.cif
# Converted: visualization/structure_21/cluster_4.xyz → visualization/structure_21/cluster_4.cif
# Converted: visualization/structure_22/train.xyz → visualization/structure_22/train.cif
# Converted: visualization/structure_22/cluster_0.xyz → visualization/structure_22/cluster_0.cif
# Converted: visualization/structure_23/train.xyz → visualization/structure_23/train.cif
# Converted: visualization/structure_23/cluster_0.xyz → visualization/structure_23/cluster_0.cif
# Converted: visualization/structure_23/cluster_1.xyz → visualization/structure_23/cluster_1.cif
# Converted: visualization/structure_24/train.xyz → visualization/structure_24/train.cif
# Converted: visualization/structure_24/cluster_0.xyz → visualization/structure_24/cluster_0.cif
# Converted: visualization/structure_24/cluster_1.xyz → visualization/structure_24/cluster_1.cif
# Converted: visualization/structure_24/cluster_2.xyz → visualization/structure_24/cluster_2.cif
# Converted: visualization/structure_24/cluster_3.xyz → visualization/structure_24/cluster_3.cif
# Converted: visualization/structure_24/cluster_4.xyz → visualization/structure_24/cluster_4.cif
# Converted: visualization/structure_24/cluster_5.xyz → visualization/structure_24/cluster_5.cif
# Converted: visualization/structure_24/cluster_6.xyz → visualization/structure_24/cluster_6.cif
# Converted: visualization/structure_24/cluster_7.xyz → visualization/structure_24/cluster_7.cif
# Converted: visualization/structure_25/train.xyz → visualization/structure_25/train.cif
# Converted: visualization/structure_25/cluster_0.xyz → visualization/structure_25/cluster_0.cif
# Converted: visualization/structure_25/cluster_1.xyz → visualization/structure_25/cluster_1.cif
# Converted: visualization/structure_25/cluster_2.xyz → visualization/structure_25/cluster_2.cif
# Converted: visualization/structure_25/cluster_3.xyz → visualization/structure_25/cluster_3.cif
# Converted: visualization/structure_25/cluster_4.xyz → visualization/structure_25/cluster_4.cif
# Converted: visualization/structure_25/cluster_5.xyz → visualization/structure_25/cluster_5.cif
# Converted: visualization/structure_26/train.xyz → visualization/structure_26/train.cif
# Converted: visualization/structure_26/cluster_0.xyz → visualization/structure_26/cluster_0.cif
# Converted: visualization/structure_26/cluster_1.xyz → visualization/structure_26/cluster_1.cif
# Converted: visualization/structure_27/train.xyz → visualization/structure_27/train.cif
# Converted: visualization/structure_27/cluster_0.xyz → visualization/structure_27/cluster_0.cif
# Converted: visualization/structure_28/train.xyz → visualization/structure_28/train.cif
# Converted: visualization/structure_28/cluster_0.xyz → visualization/structure_28/cluster_0.cif
# Converted: visualization/structure_29/train.xyz → visualization/structure_29/train.cif
# Converted: visualization/structure_29/cluster_0.xyz → visualization/structure_29/cluster_0.cif
# Converted: visualization/structure_29/cluster_1.xyz → visualization/structure_29/cluster_1.cif
# Converted: visualization/structure_30/train.xyz → visualization/structure_30/train.cif
# Converted: visualization/structure_30/cluster_0.xyz → visualization/structure_30/cluster_0.cif
# Converted: visualization/structure_30/cluster_1.xyz → visualization/structure_30/cluster_1.cif
# Converted: visualization/structure_31/train.xyz → visualization/structure_31/train.cif
# Converted: visualization/structure_31/cluster_0.xyz → visualization/structure_31/cluster_0.cif
# Converted: visualization/structure_32/train.xyz → visualization/structure_32/train.cif
# Converted: visualization/structure_32/cluster_0.xyz → visualization/structure_32/cluster_0.cif
# Converted: visualization/structure_34/train.xyz → visualization/structure_34/train.cif
# Converted: visualization/structure_34/cluster_0.xyz → visualization/structure_34/cluster_0.cif
# Converted: visualization/structure_34/cluster_1.xyz → visualization/structure_34/cluster_1.cif
# Converted: visualization/structure_34/cluster_2.xyz → visualization/structure_34/cluster_2.cif
# Converted: visualization/structure_34/cluster_3.xyz → visualization/structure_34/cluster_3.cif
# Converted: visualization/structure_34/cluster_4.xyz → visualization/structure_34/cluster_4.cif
# Converted: visualization/structure_34/cluster_5.xyz → visualization/structure_34/cluster_5.cif
# Converted: visualization/structure_34/cluster_6.xyz → visualization/structure_34/cluster_6.cif
# Converted: visualization/structure_34/cluster_7.xyz → visualization/structure_34/cluster_7.cif
# Converted: visualization/structure_35/train.xyz → visualization/structure_35/train.cif
# Converted: visualization/structure_35/cluster_0.xyz → visualization/structure_35/cluster_0.cif
# Converted: visualization/structure_35/cluster_1.xyz → visualization/structure_35/cluster_1.cif
# Converted: visualization/structure_35/cluster_2.xyz → visualization/structure_35/cluster_2.cif
# Converted: visualization/structure_36/train.xyz → visualization/structure_36/train.cif
# Converted: visualization/structure_36/cluster_0.xyz → visualization/structure_36/cluster_0.cif
# Converted: visualization/structure_36/cluster_1.xyz → visualization/structure_36/cluster_1.cif
# Converted: visualization/structure_36/cluster_2.xyz → visualization/structure_36/cluster_2.cif
# Converted: visualization/structure_36/cluster_3.xyz → visualization/structure_36/cluster_3.cif
# Converted: visualization/structure_36/cluster_4.xyz → visualization/structure_36/cluster_4.cif
# Converted: visualization/structure_37/train.xyz → visualization/structure_37/train.cif
# Converted: visualization/structure_37/cluster_0.xyz → visualization/structure_37/cluster_0.cif
# Converted: visualization/structure_37/cluster_1.xyz → visualization/structure_37/cluster_1.cif
# Converted: visualization/structure_38/train.xyz → visualization/structure_38/train.cif
# Converted: visualization/structure_38/cluster_0.xyz → visualization/structure_38/cluster_0.cif
# Converted: visualization/structure_38/cluster_1.xyz → visualization/structure_38/cluster_1.cif
# Converted: visualization/structure_38/cluster_2.xyz → visualization/structure_38/cluster_2.cif
# Converted: visualization/structure_38/cluster_3.xyz → visualization/structure_38/cluster_3.cif
# Converted: visualization/structure_38/cluster_4.xyz → visualization/structure_38/cluster_4.cif
# Converted: visualization/structure_39/train.xyz → visualization/structure_39/train.cif
# Converted: visualization/structure_39/cluster_0.xyz → visualization/structure_39/cluster_0.cif
# Converted: visualization/structure_39/cluster_1.xyz → visualization/structure_39/cluster_1.cif
# Converted: visualization/structure_39/cluster_2.xyz → visualization/structure_39/cluster_2.cif
# Converted: visualization/structure_39/cluster_3.xyz → visualization/structure_39/cluster_3.cif
# Converted: visualization/structure_39/cluster_4.xyz → visualization/structure_39/cluster_4.cif
# Converted: visualization/structure_39/cluster_5.xyz → visualization/structure_39/cluster_5.cif
# Converted: visualization/structure_40/train.xyz → visualization/structure_40/train.cif
# Converted: visualization/structure_40/cluster_0.xyz → visualization/structure_40/cluster_0.cif
# Converted: visualization/structure_41/train.xyz → visualization/structure_41/train.cif
# Converted: visualization/structure_41/cluster_0.xyz → visualization/structure_41/cluster_0.cif
# Converted: visualization/structure_41/cluster_1.xyz → visualization/structure_41/cluster_1.cif
# Converted: visualization/structure_42/train.xyz → visualization/structure_42/train.cif
# Converted: visualization/structure_42/cluster_0.xyz → visualization/structure_42/cluster_0.cif
# Converted: visualization/structure_42/cluster_1.xyz → visualization/structure_42/cluster_1.cif
# Converted: visualization/structure_42/cluster_2.xyz → visualization/structure_42/cluster_2.cif
# Converted: visualization/structure_42/cluster_3.xyz → visualization/structure_42/cluster_3.cif
# Converted: visualization/structure_43/train.xyz → visualization/structure_43/train.cif
# Converted: visualization/structure_43/cluster_0.xyz → visualization/structure_43/cluster_0.cif
# Converted: visualization/structure_43/cluster_1.xyz → visualization/structure_43/cluster_1.cif
# Converted: visualization/structure_44/train.xyz → visualization/structure_44/train.cif
# Converted: visualization/structure_44/cluster_0.xyz → visualization/structure_44/cluster_0.cif
# Converted: visualization/structure_44/cluster_1.xyz → visualization/structure_44/cluster_1.cif
# Converted: visualization/structure_44/cluster_2.xyz → visualization/structure_44/cluster_2.cif
# Converted: visualization/structure_44/cluster_3.xyz → visualization/structure_44/cluster_3.cif
# Converted: visualization/structure_44/cluster_4.xyz → visualization/structure_44/cluster_4.cif
# Converted: visualization/structure_45/train.xyz → visualization/structure_45/train.cif
# Converted: visualization/structure_45/cluster_0.xyz → visualization/structure_45/cluster_0.cif
# Converted: visualization/structure_45/cluster_1.xyz → visualization/structure_45/cluster_1.cif
# Converted: visualization/structure_45/cluster_2.xyz → visualization/structure_45/cluster_2.cif
# Converted: visualization/structure_45/cluster_3.xyz → visualization/structure_45/cluster_3.cif
# Converted: visualization/structure_45/cluster_4.xyz → visualization/structure_45/cluster_4.cif
# Converted: visualization/structure_46/train.xyz → visualization/structure_46/train.cif
# Converted: visualization/structure_46/cluster_0.xyz → visualization/structure_46/cluster_0.cif
# Converted: visualization/structure_46/cluster_1.xyz → visualization/structure_46/cluster_1.cif
# Converted: visualization/structure_47/train.xyz → visualization/structure_47/train.cif
# Converted: visualization/structure_47/cluster_0.xyz → visualization/structure_47/cluster_0.cif
# Converted: visualization/structure_47/cluster_1.xyz → visualization/structure_47/cluster_1.cif
# Converted: visualization/structure_47/cluster_2.xyz → visualization/structure_47/cluster_2.cif
# Converted: visualization/structure_47/cluster_3.xyz → visualization/structure_47/cluster_3.cif
# Converted: visualization/structure_48/train.xyz → visualization/structure_48/train.cif
# Converted: visualization/structure_48/cluster_0.xyz → visualization/structure_48/cluster_0.cif
# Converted: visualization/structure_48/cluster_1.xyz → visualization/structure_48/cluster_1.cif
# Converted: visualization/structure_48/cluster_2.xyz → visualization/structure_48/cluster_2.cif
# Converted: visualization/structure_48/cluster_3.xyz → visualization/structure_48/cluster_3.cif
# Converted: visualization/structure_48/cluster_4.xyz → visualization/structure_48/cluster_4.cif
# Converted: visualization/structure_48/cluster_5.xyz → visualization/structure_48/cluster_5.cif
# Converted: visualization/structure_49/train.xyz → visualization/structure_49/train.cif
# Converted: visualization/structure_49/cluster_0.xyz → visualization/structure_49/cluster_0.cif
# Converted: visualization/structure_49/cluster_1.xyz → visualization/structure_49/cluster_1.cif
# Converted: visualization/structure_49/cluster_2.xyz → visualization/structure_49/cluster_2.cif
# Converted: visualization/structure_49/cluster_3.xyz → visualization/structure_49/cluster_3.cif
# Converted: visualization/structure_49/cluster_4.xyz → visualization/structure_49/cluster_4.cif
# Converted: visualization/structure_49/cluster_5.xyz → visualization/structure_49/cluster_5.cif
# Converted: visualization/structure_49/cluster_6.xyz → visualization/structure_49/cluster_6.cif
# Converted: visualization/structure_50/train.xyz → visualization/structure_50/train.cif
# Converted: visualization/structure_50/cluster_0.xyz → visualization/structure_50/cluster_0.cif
# Converted: visualization/structure_50/cluster_1.xyz → visualization/structure_50/cluster_1.cif
# Converted: visualization/structure_51/train.xyz → visualization/structure_51/train.cif
# Converted: visualization/structure_51/cluster_0.xyz → visualization/structure_51/cluster_0.cif
# Converted: visualization/structure_52/train.xyz → visualization/structure_52/train.cif
# Converted: visualization/structure_52/cluster_0.xyz → visualization/structure_52/cluster_0.cif
# Converted: visualization/structure_52/cluster_1.xyz → visualization/structure_52/cluster_1.cif
# Converted: visualization/structure_53/train.xyz → visualization/structure_53/train.cif
# Converted: visualization/structure_53/cluster_0.xyz → visualization/structure_53/cluster_0.cif
# Converted: visualization/structure_53/cluster_1.xyz → visualization/structure_53/cluster_1.cif
# Converted: visualization/structure_54/train.xyz → visualization/structure_54/train.cif
# Converted: visualization/structure_54/cluster_0.xyz → visualization/structure_54/cluster_0.cif
# Converted: visualization/structure_55/train.xyz → visualization/structure_55/train.cif
# Converted: visualization/structure_55/cluster_0.xyz → visualization/structure_55/cluster_0.cif
# Converted: visualization/structure_55/cluster_1.xyz → visualization/structure_55/cluster_1.cif
# Converted: visualization/structure_56/train.xyz → visualization/structure_56/train.cif
# Converted: visualization/structure_56/cluster_0.xyz → visualization/structure_56/cluster_0.cif
# Converted: visualization/structure_56/cluster_1.xyz → visualization/structure_56/cluster_1.cif
# Converted: visualization/structure_57/train.xyz → visualization/structure_57/train.cif
# Converted: visualization/structure_57/cluster_0.xyz → visualization/structure_57/cluster_0.cif
# Converted: visualization/structure_57/cluster_1.xyz → visualization/structure_57/cluster_1.cif
# Converted: visualization/structure_58/train.xyz → visualization/structure_58/train.cif
# Converted: visualization/structure_58/cluster_0.xyz → visualization/structure_58/cluster_0.cif
# Converted: visualization/structure_58/cluster_1.xyz → visualization/structure_58/cluster_1.cif
# Converted: visualization/structure_58/cluster_2.xyz → visualization/structure_58/cluster_2.cif
# Converted: visualization/structure_59/train.xyz → visualization/structure_59/train.cif
# Converted: visualization/structure_59/cluster_0.xyz → visualization/structure_59/cluster_0.cif
# Converted: visualization/structure_59/cluster_1.xyz → visualization/structure_59/cluster_1.cif
# Converted: visualization/structure_60/train.xyz → visualization/structure_60/train.cif
# Converted: visualization/structure_60/cluster_0.xyz → visualization/structure_60/cluster_0.cif
# Converted: visualization/structure_60/cluster_1.xyz → visualization/structure_60/cluster_1.cif
# Converted: visualization/structure_60/cluster_2.xyz → visualization/structure_60/cluster_2.cif
# Converted: visualization/structure_60/cluster_3.xyz → visualization/structure_60/cluster_3.cif
# Converted: visualization/structure_60/cluster_4.xyz → visualization/structure_60/cluster_4.cif
# Converted: visualization/structure_60/cluster_5.xyz → visualization/structure_60/cluster_5.cif
# Converted: visualization/structure_60/cluster_6.xyz → visualization/structure_60/cluster_6.cif
# Converted: visualization/structure_60/cluster_7.xyz → visualization/structure_60/cluster_7.cif
# Converted: visualization/structure_60/cluster_8.xyz → visualization/structure_60/cluster_8.cif
# Converted: visualization/structure_60/cluster_9.xyz → visualization/structure_60/cluster_9.cif
# Converted: visualization/structure_60/cluster_10.xyz → visualization/structure_60/cluster_10.cif
# Converted: visualization/structure_60/cluster_11.xyz → visualization/structure_60/cluster_11.cif
# Converted: visualization/structure_60/cluster_12.xyz → visualization/structure_60/cluster_12.cif
# Converted: visualization/structure_60/cluster_13.xyz → visualization/structure_60/cluster_13.cif
# Converted: visualization/structure_60/cluster_14.xyz → visualization/structure_60/cluster_14.cif
# Converted: visualization/structure_60/cluster_15.xyz → visualization/structure_60/cluster_15.cif
# Converted: visualization/structure_60/cluster_16.xyz → visualization/structure_60/cluster_16.cif
# Converted: visualization/structure_61/train.xyz → visualization/structure_61/train.cif
# Converted: visualization/structure_61/cluster_0.xyz → visualization/structure_61/cluster_0.cif
# Converted: visualization/structure_61/cluster_1.xyz → visualization/structure_61/cluster_1.cif
# Converted: visualization/structure_62/train.xyz → visualization/structure_62/train.cif
# Converted: visualization/structure_62/cluster_0.xyz → visualization/structure_62/cluster_0.cif
# Converted: visualization/structure_62/cluster_1.xyz → visualization/structure_62/cluster_1.cif
# Converted: visualization/structure_62/cluster_2.xyz → visualization/structure_62/cluster_2.cif
# Converted: visualization/structure_63/train.xyz → visualization/structure_63/train.cif
# Converted: visualization/structure_63/cluster_0.xyz → visualization/structure_63/cluster_0.cif
# Converted: visualization/structure_63/cluster_1.xyz → visualization/structure_63/cluster_1.cif
# Converted: visualization/structure_64/train.xyz → visualization/structure_64/train.cif
# Converted: visualization/structure_64/cluster_0.xyz → visualization/structure_64/cluster_0.cif
# Converted: visualization/structure_64/cluster_1.xyz → visualization/structure_64/cluster_1.cif
# Converted: visualization/structure_65/train.xyz → visualization/structure_65/train.cif
# Converted: visualization/structure_65/cluster_0.xyz → visualization/structure_65/cluster_0.cif
# Converted: visualization/structure_65/cluster_1.xyz → visualization/structure_65/cluster_1.cif
# Converted: visualization/structure_66/train.xyz → visualization/structure_66/train.cif
# Converted: visualization/structure_66/cluster_0.xyz → visualization/structure_66/cluster_0.cif
# Converted: visualization/structure_66/cluster_1.xyz → visualization/structure_66/cluster_1.cif
# Converted: visualization/structure_66/cluster_2.xyz → visualization/structure_66/cluster_2.cif
# Converted: visualization/structure_67/train.xyz → visualization/structure_67/train.cif
# Converted: visualization/structure_67/cluster_0.xyz → visualization/structure_67/cluster_0.cif
# Converted: visualization/structure_67/cluster_1.xyz → visualization/structure_67/cluster_1.cif
# Converted: visualization/structure_68/train.xyz → visualization/structure_68/train.cif
# Converted: visualization/structure_68/cluster_0.xyz → visualization/structure_68/cluster_0.cif
# Converted: visualization/structure_68/cluster_1.xyz → visualization/structure_68/cluster_1.cif
# Converted: visualization/structure_69/train.xyz → visualization/structure_69/train.cif
# Converted: visualization/structure_69/cluster_0.xyz → visualization/structure_69/cluster_0.cif
# Converted: visualization/structure_70/train.xyz → visualization/structure_70/train.cif
# Converted: visualization/structure_70/cluster_0.xyz → visualization/structure_70/cluster_0.cif
# Converted: visualization/structure_70/cluster_1.xyz → visualization/structure_70/cluster_1.cif
# Converted: visualization/structure_70/cluster_2.xyz → visualization/structure_70/cluster_2.cif
# Converted: visualization/structure_70/cluster_3.xyz → visualization/structure_70/cluster_3.cif
# Converted: visualization/structure_70/cluster_4.xyz → visualization/structure_70/cluster_4.cif
# Converted: visualization/structure_70/cluster_5.xyz → visualization/structure_70/cluster_5.cif
# Converted: visualization/structure_70/cluster_6.xyz → visualization/structure_70/cluster_6.cif
# Converted: visualization/structure_70/cluster_7.xyz → visualization/structure_70/cluster_7.cif
# Converted: visualization/structure_70/cluster_8.xyz → visualization/structure_70/cluster_8.cif
# Converted: visualization/structure_70/cluster_9.xyz → visualization/structure_70/cluster_9.cif
# Converted: visualization/structure_70/cluster_10.xyz → visualization/structure_70/cluster_10.cif
# Converted: visualization/structure_70/cluster_11.xyz → visualization/structure_70/cluster_11.cif
# Converted: visualization/structure_70/cluster_12.xyz → visualization/structure_70/cluster_12.cif
# Converted: visualization/structure_70/cluster_13.xyz → visualization/structure_70/cluster_13.cif
# Converted: visualization/structure_70/cluster_14.xyz → visualization/structure_70/cluster_14.cif
# Converted: visualization/structure_70/cluster_15.xyz → visualization/structure_70/cluster_15.cif
# Converted: visualization/structure_70/cluster_16.xyz → visualization/structure_70/cluster_16.cif
# Converted: visualization/structure_70/cluster_17.xyz → visualization/structure_70/cluster_17.cif
# Converted: visualization/structure_70/cluster_18.xyz → visualization/structure_70/cluster_18.cif
# Converted: visualization/structure_70/cluster_19.xyz → visualization/structure_70/cluster_19.cif
# Converted: visualization/structure_70/cluster_20.xyz → visualization/structure_70/cluster_20.cif
# Converted: visualization/structure_70/cluster_21.xyz → visualization/structure_70/cluster_21.cif
# Converted: visualization/structure_70/cluster_22.xyz → visualization/structure_70/cluster_22.cif
# Converted: visualization/structure_71/train.xyz → visualization/structure_71/train.cif
# Converted: visualization/structure_71/cluster_0.xyz → visualization/structure_71/cluster_0.cif
# Converted: visualization/structure_71/cluster_1.xyz → visualization/structure_71/cluster_1.cif
# Converted: visualization/structure_71/cluster_2.xyz → visualization/structure_71/cluster_2.cif
# Converted: visualization/structure_72/train.xyz → visualization/structure_72/train.cif
# Converted: visualization/structure_72/cluster_0.xyz → visualization/structure_72/cluster_0.cif
# Converted: visualization/structure_72/cluster_1.xyz → visualization/structure_72/cluster_1.cif
# Converted: visualization/structure_73/train.xyz → visualization/structure_73/train.cif
# Converted: visualization/structure_73/cluster_0.xyz → visualization/structure_73/cluster_0.cif
# Converted: visualization/structure_74/train.xyz → visualization/structure_74/train.cif
# Converted: visualization/structure_74/cluster_0.xyz → visualization/structure_74/cluster_0.cif
# Converted: visualization/structure_74/cluster_1.xyz → visualization/structure_74/cluster_1.cif
# Converted: visualization/structure_74/cluster_2.xyz → visualization/structure_74/cluster_2.cif
# Converted: visualization/structure_74/cluster_3.xyz → visualization/structure_74/cluster_3.cif
# Converted: visualization/structure_75/train.xyz → visualization/structure_75/train.cif
# Converted: visualization/structure_75/cluster_0.xyz → visualization/structure_75/cluster_0.cif
# Converted: visualization/structure_76/train.xyz → visualization/structure_76/train.cif
# Converted: visualization/structure_76/cluster_0.xyz → visualization/structure_76/cluster_0.cif
# Converted: visualization/structure_76/cluster_1.xyz → visualization/structure_76/cluster_1.cif
# Converted: visualization/structure_77/train.xyz → visualization/structure_77/train.cif
# Converted: visualization/structure_77/cluster_0.xyz → visualization/structure_77/cluster_0.cif
# Converted: visualization/structure_77/cluster_1.xyz → visualization/structure_77/cluster_1.cif
# Converted: visualization/structure_77/cluster_2.xyz → visualization/structure_77/cluster_2.cif
# Converted: visualization/structure_77/cluster_3.xyz → visualization/structure_77/cluster_3.cif
# Converted: visualization/structure_78/train.xyz → visualization/structure_78/train.cif
# Converted: visualization/structure_78/cluster_0.xyz → visualization/structure_78/cluster_0.cif
# Converted: visualization/structure_78/cluster_1.xyz → visualization/structure_78/cluster_1.cif
# Converted: visualization/structure_79/train.xyz → visualization/structure_79/train.cif
# Converted: visualization/structure_79/cluster_0.xyz → visualization/structure_79/cluster_0.cif
# Converted: visualization/structure_79/cluster_1.xyz → visualization/structure_79/cluster_1.cif
# Converted: visualization/structure_79/cluster_2.xyz → visualization/structure_79/cluster_2.cif
# Converted: visualization/structure_79/cluster_3.xyz → visualization/structure_79/cluster_3.cif
# Converted: visualization/structure_79/cluster_4.xyz → visualization/structure_79/cluster_4.cif
# Converted: visualization/structure_79/cluster_5.xyz → visualization/structure_79/cluster_5.cif
# Converted: visualization/structure_79/cluster_6.xyz → visualization/structure_79/cluster_6.cif
# Converted: visualization/structure_80/train.xyz → visualization/structure_80/train.cif
# Converted: visualization/structure_80/cluster_0.xyz → visualization/structure_80/cluster_0.cif
# Converted: visualization/structure_80/cluster_1.xyz → visualization/structure_80/cluster_1.cif
# Converted: visualization/structure_81/train.xyz → visualization/structure_81/train.cif
# Converted: visualization/structure_81/cluster_0.xyz → visualization/structure_81/cluster_0.cif
# Converted: visualization/structure_81/cluster_1.xyz → visualization/structure_81/cluster_1.cif
# Converted: visualization/structure_81/cluster_2.xyz → visualization/structure_81/cluster_2.cif
# Converted: visualization/structure_81/cluster_3.xyz → visualization/structure_81/cluster_3.cif
# Converted: visualization/structure_81/cluster_4.xyz → visualization/structure_81/cluster_4.cif
# Converted: visualization/structure_81/cluster_5.xyz → visualization/structure_81/cluster_5.cif
# Converted: visualization/structure_81/cluster_6.xyz → visualization/structure_81/cluster_6.cif
# Converted: visualization/structure_81/cluster_7.xyz → visualization/structure_81/cluster_7.cif
# Converted: visualization/structure_81/cluster_8.xyz → visualization/structure_81/cluster_8.cif
# Converted: visualization/structure_81/cluster_9.xyz → visualization/structure_81/cluster_9.cif
# Converted: visualization/structure_81/cluster_10.xyz → visualization/structure_81/cluster_10.cif
# Converted: visualization/structure_81/cluster_11.xyz → visualization/structure_81/cluster_11.cif
# Converted: visualization/structure_81/cluster_12.xyz → visualization/structure_81/cluster_12.cif
# Converted: visualization/structure_81/cluster_13.xyz → visualization/structure_81/cluster_13.cif
# Converted: visualization/structure_81/cluster_14.xyz → visualization/structure_81/cluster_14.cif
# Converted: visualization/structure_81/cluster_15.xyz → visualization/structure_81/cluster_15.cif
# Converted: visualization/structure_81/cluster_16.xyz → visualization/structure_81/cluster_16.cif
# Converted: visualization/structure_81/cluster_17.xyz → visualization/structure_81/cluster_17.cif
# Converted: visualization/structure_81/cluster_18.xyz → visualization/structure_81/cluster_18.cif
# Converted: visualization/structure_81/cluster_19.xyz → visualization/structure_81/cluster_19.cif
# Converted: visualization/structure_81/cluster_20.xyz → visualization/structure_81/cluster_20.cif
# Converted: visualization/structure_82/train.xyz → visualization/structure_82/train.cif
# Converted: visualization/structure_82/cluster_0.xyz → visualization/structure_82/cluster_0.cif
# Converted: visualization/structure_82/cluster_1.xyz → visualization/structure_82/cluster_1.cif
# Converted: visualization/structure_82/cluster_2.xyz → visualization/structure_82/cluster_2.cif
# Converted: visualization/structure_83/train.xyz → visualization/structure_83/train.cif
# Converted: visualization/structure_83/cluster_0.xyz → visualization/structure_83/cluster_0.cif
# Converted: visualization/structure_83/cluster_1.xyz → visualization/structure_83/cluster_1.cif
# Converted: visualization/structure_84/train.xyz → visualization/structure_84/train.cif
# Converted: visualization/structure_84/cluster_0.xyz → visualization/structure_84/cluster_0.cif
# Converted: visualization/structure_84/cluster_1.xyz → visualization/structure_84/cluster_1.cif
# Converted: visualization/structure_84/cluster_2.xyz → visualization/structure_84/cluster_2.cif
# Converted: visualization/structure_84/cluster_3.xyz → visualization/structure_84/cluster_3.cif
# Converted: visualization/structure_85/train.xyz → visualization/structure_85/train.cif
# Converted: visualization/structure_85/cluster_0.xyz → visualization/structure_85/cluster_0.cif
# Converted: visualization/structure_85/cluster_1.xyz → visualization/structure_85/cluster_1.cif
# Converted: visualization/structure_85/cluster_2.xyz → visualization/structure_85/cluster_2.cif
# Converted: visualization/structure_85/cluster_3.xyz → visualization/structure_85/cluster_3.cif
# Converted: visualization/structure_85/cluster_4.xyz → visualization/structure_85/cluster_4.cif
# Converted: visualization/structure_85/cluster_5.xyz → visualization/structure_85/cluster_5.cif
# Converted: visualization/structure_85/cluster_6.xyz → visualization/structure_85/cluster_6.cif
# Converted: visualization/structure_85/cluster_7.xyz → visualization/structure_85/cluster_7.cif
# Converted: visualization/structure_85/cluster_8.xyz → visualization/structure_85/cluster_8.cif
# Converted: visualization/structure_85/cluster_9.xyz → visualization/structure_85/cluster_9.cif
# Converted: visualization/structure_86/train.xyz → visualization/structure_86/train.cif
# Converted: visualization/structure_86/cluster_0.xyz → visualization/structure_86/cluster_0.cif
# Converted: visualization/structure_86/cluster_1.xyz → visualization/structure_86/cluster_1.cif
# Converted: visualization/structure_87/train.xyz → visualization/structure_87/train.cif
# Converted: visualization/structure_87/cluster_0.xyz → visualization/structure_87/cluster_0.cif
# Converted: visualization/structure_87/cluster_1.xyz → visualization/structure_87/cluster_1.cif
# Converted: visualization/structure_88/train.xyz → visualization/structure_88/train.cif
# Converted: visualization/structure_88/cluster_0.xyz → visualization/structure_88/cluster_0.cif
# Converted: visualization/structure_89/train.xyz → visualization/structure_89/train.cif
# Converted: visualization/structure_89/cluster_0.xyz → visualization/structure_89/cluster_0.cif
# Converted: visualization/structure_89/cluster_1.xyz → visualization/structure_89/cluster_1.cif
# Converted: visualization/structure_89/cluster_2.xyz → visualization/structure_89/cluster_2.cif
# Converted: visualization/structure_89/cluster_3.xyz → visualization/structure_89/cluster_3.cif
# Converted: visualization/structure_89/cluster_4.xyz → visualization/structure_89/cluster_4.cif
# Converted: visualization/structure_89/cluster_5.xyz → visualization/structure_89/cluster_5.cif
# Converted: visualization/structure_90/train.xyz → visualization/structure_90/train.cif
# Converted: visualization/structure_90/cluster_0.xyz → visualization/structure_90/cluster_0.cif
# Converted: visualization/structure_91/train.xyz → visualization/structure_91/train.cif
# Converted: visualization/structure_91/cluster_0.xyz → visualization/structure_91/cluster_0.cif
# Converted: visualization/structure_91/cluster_1.xyz → visualization/structure_91/cluster_1.cif
# Converted: visualization/structure_92/train.xyz → visualization/structure_92/train.cif
# Converted: visualization/structure_92/cluster_0.xyz → visualization/structure_92/cluster_0.cif
# Converted: visualization/structure_92/cluster_1.xyz → visualization/structure_92/cluster_1.cif
# Converted: visualization/structure_93/train.xyz → visualization/structure_93/train.cif
# Converted: visualization/structure_93/cluster_0.xyz → visualization/structure_93/cluster_0.cif
# Converted: visualization/structure_93/cluster_1.xyz → visualization/structure_93/cluster_1.cif
# Converted: visualization/structure_93/cluster_2.xyz → visualization/structure_93/cluster_2.cif
# Converted: visualization/structure_94/train.xyz → visualization/structure_94/train.cif
# Converted: visualization/structure_94/cluster_0.xyz → visualization/structure_94/cluster_0.cif
# Converted: visualization/structure_94/cluster_1.xyz → visualization/structure_94/cluster_1.cif
# Converted: visualization/structure_94/cluster_2.xyz → visualization/structure_94/cluster_2.cif
# Converted: visualization/structure_94/cluster_3.xyz → visualization/structure_94/cluster_3.cif
# Converted: visualization/structure_94/cluster_4.xyz → visualization/structure_94/cluster_4.cif
# Converted: visualization/structure_94/cluster_5.xyz → visualization/structure_94/cluster_5.cif
# Converted: visualization/structure_94/cluster_6.xyz → visualization/structure_94/cluster_6.cif
# Converted: visualization/structure_94/cluster_7.xyz → visualization/structure_94/cluster_7.cif
# Converted: visualization/structure_94/cluster_8.xyz → visualization/structure_94/cluster_8.cif
# Converted: visualization/structure_94/cluster_9.xyz → visualization/structure_94/cluster_9.cif
# Converted: visualization/structure_94/cluster_10.xyz → visualization/structure_94/cluster_10.cif
# Converted: visualization/structure_94/cluster_11.xyz → visualization/structure_94/cluster_11.cif
# Converted: visualization/structure_94/cluster_12.xyz → visualization/structure_94/cluster_12.cif
# Converted: visualization/structure_94/cluster_13.xyz → visualization/structure_94/cluster_13.cif
# Converted: visualization/structure_94/cluster_14.xyz → visualization/structure_94/cluster_14.cif
# Converted: visualization/structure_95/train.xyz → visualization/structure_95/train.cif
# Converted: visualization/structure_95/cluster_0.xyz → visualization/structure_95/cluster_0.cif
# Converted: visualization/structure_95/cluster_1.xyz → visualization/structure_95/cluster_1.cif
# Converted: visualization/structure_96/train.xyz → visualization/structure_96/train.cif
# Converted: visualization/structure_96/cluster_0.xyz → visualization/structure_96/cluster_0.cif
# Converted: visualization/structure_97/train.xyz → visualization/structure_97/train.cif
# Converted: visualization/structure_97/cluster_0.xyz → visualization/structure_97/cluster_0.cif
# Converted: visualization/structure_97/cluster_1.xyz → visualization/structure_97/cluster_1.cif
# Converted: visualization/structure_97/cluster_2.xyz → visualization/structure_97/cluster_2.cif
# Converted: visualization/structure_98/train.xyz → visualization/structure_98/train.cif
# Converted: visualization/structure_98/cluster_0.xyz → visualization/structure_98/cluster_0.cif
# Converted: visualization/structure_98/cluster_1.xyz → visualization/structure_98/cluster_1.cif
# Converted: visualization/structure_98/cluster_2.xyz → visualization/structure_98/cluster_2.cif
# Converted: visualization/structure_99/train.xyz → visualization/structure_99/train.cif
# Converted: visualization/structure_99/cluster_0.xyz → visualization/structure_99/cluster_0.cif
